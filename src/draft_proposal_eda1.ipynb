# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/DATA-606-SPRING-2023-TUE/Sivaji_Data_606/main/Data/AH_Monthly_Provisional_Counts_of_Deaths_for_Select_Causes_of_Death_by_Sex__Age__and_Race_and_Hispanic_Origin.csv")

# %%
data
# Out:
#      AnalysisDate  Date Of Death Year  Date Of Death Month  Start Date  \
# 0      10/13/2021                2019                    7  07/01/2019
# 1      10/13/2021                2019                    9  09/01/2019
# 2      10/13/2021                2020                    3  03/01/2020
# 3      10/13/2021                2020                    3  03/01/2020
# 4      10/13/2021                2020                    3  03/01/2020
# ...           ...                 ...                  ...         ...
# 3955   10/13/2021                2021                    9  09/01/2021
# 3956   10/13/2021                2021                    9  09/01/2021
# 3957   10/13/2021                2021                    9  09/01/2021
# 3958   10/13/2021                2021                    9  09/01/2021
# 3959   10/13/2021                2021                    9  09/01/2021
#
#         End Date Jurisdiction of Occurrence     Sex Race/Ethnicity  \
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of      AnalysisDate  Date Of Death Year  Date Of Death Month  Start Date  \
# 0      10/13/2021                2019                    7  07/01/2019
# 1      10/13/2021                2019                    9  09/01/2019
# 2      10/13/2021                2020                    3  03/01/2020
# 3      10/13/2021                2020                    3  03/01/2020
# 4      10/13/2021                2020                    3  03/01/2020
# ...           ...                 ...                  ...         ...
# 3955   10/13/2021                2021                    9  09/01/2021
# 3956   10/13/2021                2021                    9  09/01/2021
# 3957   10/13/2021                2021                    9  09/01/2021
# 3958   10/13/2021                2021                    9  09/01/2021
# 3959   10/13/2021                2021                    9  09/01/2021
#
#         End Date Jurisdiction of Occurrence     Sex Race/Ethnicity  \
# ...

# %%
data.shape
# Out:
# (3960, 24)

# %%
data.dtypes
# Out:
# AnalysisDate                                                                                         object
# Date Of Death Year                                                                                    int64
# Date Of Death Month                                                                                   int64
# Start Date                                                                                           object
# End Date                                                                                             object
# Jurisdiction of Occurrence                                                                           object
# Sex                                                                                                  object
# Race/Ethnicity                                                                                       object
# AgeGroup                                                                                             object
# ...

# %%
data.describe()
# Out:
#        Date Of Death Year  Date Of Death Month      AllCause  NaturalCause  \
# count         3960.000000          3960.000000   3960.000000   3960.000000
# mean          2019.909091             6.090909   2198.036364   2013.427778
# std              0.792627             3.306643   5911.709190   5703.836760
# min           2019.000000             1.000000      0.000000      0.000000
# 25%           2019.000000             3.000000     73.000000     45.000000
# 50%           2020.000000             6.000000    247.000000    187.000000
# 75%           2021.000000             9.000000   1423.500000   1111.000000
# max           2021.000000            12.000000  55227.000000  53946.000000
#
#        Septicemia (A40-A41)  Malignant neoplasms (C00-C97)  \
# count           3960.000000                    3960.000000
# mean              27.073737                     413.974495
# std               69.925444                    1134.575944
# ...

# %%
data.count()
# Out:
# AnalysisDate                                                                                         3960
# Date Of Death Year                                                                                   3960
# Date Of Death Month                                                                                  3960
# Start Date                                                                                           3960
# End Date                                                                                             3960
# Jurisdiction of Occurrence                                                                           3960
# Sex                                                                                                  3960
# Race/Ethnicity                                                                                       3960
# AgeGroup                                                                                             3960
# ...

# %%
data.isnull().sum()
# Out:
# AnalysisDate                                                                                         0
# Date Of Death Year                                                                                   0
# Date Of Death Month                                                                                  0
# Start Date                                                                                           0
# End Date                                                                                             0
# Jurisdiction of Occurrence                                                                           0
# Sex                                                                                                  0
# Race/Ethnicity                                                                                       0
# AgeGroup                                                                                             0
# ...

# %%
data['Diseases of heart (I00-I09,I11,I13,I20-I51)'].value_counts().head(10).plot.bar( figsize = (25, 15))
plt.title('Heart Disease patients', fontweight = 30, fontsize = 20)
plt.show()

# %%
data['NaturalCause'].value_counts().head(10).plot.bar( figsize = (25, 15))
plt.title('Natural cause death patients', fontweight = 30, fontsize = 20)
plt.show()
