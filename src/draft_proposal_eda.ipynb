# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/DATA-606-SPRING-2023-TUE/Sivaji_Data_606/main/Data/Missouri_Active_Alcohol_License_Data.csv")

# %%
data
# Out:
#                                       LICENSEE  \
# 0                             JAVA & HOOCH LLC
# 1              CONVENTION HOSPITALITY PARTNERS
# 2      LEVY PREMIUM FOOD SERVICE LIMITED PART.
# 3       CITY LIMITS RESTAURANT AND SPIRITS LLC
# 4                                  LUXCO, INC.
# ...                                        ...
# 18418                MISSOURI CVS PHARMACY LLC
# 18419                 MOD SUPER FAST PIZZA LLC
# 18420                 SHAKE SHACK MISSOURI LLC
# 18421                          DOLGENCORP, LLC
# 18422                   JEFFERSON CITY JAYCEES
#
#                                         DBANAME STREET NUMBER  \
# 0                                  JAVA & HOOCH          2811
# 1               CONVENTION HOSPITALITY PARTNERS           701
# 2      SCOTTRADE CENTER-LEVEL 1 & SUMMER GARDEN          1401
# 3            CITY LIMITS RESTAURANT AND SPIRITS           662
# 4                          PARAMOUNT DISTILLERS          3116
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of                                       LICENSEE  \
# 0                             JAVA & HOOCH LLC
# 1              CONVENTION HOSPITALITY PARTNERS
# 2      LEVY PREMIUM FOOD SERVICE LIMITED PART.
# 3       CITY LIMITS RESTAURANT AND SPIRITS LLC
# 4                                  LUXCO, INC.
# ...                                        ...
# 18418                MISSOURI CVS PHARMACY LLC
# 18419                 MOD SUPER FAST PIZZA LLC
# 18420                 SHAKE SHACK MISSOURI LLC
# 18421                          DOLGENCORP, LLC
# 18422                   JEFFERSON CITY JAYCEES
#
#                                         DBANAME STREET NUMBER  \
# 0                                  JAVA & HOOCH          2811
# 1               CONVENTION HOSPITALITY PARTNERS           701
# 2      SCOTTRADE CENTER-LEVEL 1 & SUMMER GARDEN          1401
# 3            CITY LIMITS RESTAURANT AND SPIRITS           662
# ...

# %%
data.shape
# Out:
# (18423, 20)

# %%
data.dtypes
# Out:
# LICENSEE              object
# DBANAME               object
# STREET NUMBER         object
# STREET                object
# CITY                  object
# STATE                 object
# ZIPCODE              float64
# PHONE NUMBER           int64
# PRIMARY LICENSE        int64
# SECONDARY LICENSE      int64
# PRIMARY TYPE          object
# SECONDARY TYPE        object
# COUNTY                object
# DISTRICT               int64
# SUBDIST                int64
# LATLNG                object
# Assoc                 object
# First Name            object
# Last Name             object
# Phone                  int64
# dtype: object

# %%
data.describe()
# Out:
#             ZIPCODE  PHONE NUMBER  PRIMARY LICENSE  SECONDARY LICENSE  \
# count  1.842200e+04  1.842300e+04     18423.000000       18423.000000
# mean   2.996639e+08  5.606214e+09    216731.330891      148609.855778
# std    3.556016e+08  1.965243e+09     67383.864667      115322.151539
# min    6.800000e+01  0.000000e+00         7.000000           0.000000
# 25%    6.403000e+04  4.173593e+09    179202.000000           0.000000
# 50%    6.570800e+04  5.736354e+09    238640.000000      185815.000000
# 75%    6.405561e+08  7.072656e+09    270808.000000      258739.500000
# max    9.980195e+08  1.000000e+10    289445.000000      289447.000000
#
#            DISTRICT       SUBDIST         Phone
# count  18423.000000  18423.000000  1.842300e+04
# mean       3.405254      0.004180  5.463606e+09
# std        1.937387      0.567297  2.015594e+09
# min        1.000000      0.000000 -8.568408e+09
# 25%        2.000000      0.000000  3.217902e+09
# ...

# %%
data.count()
# Out:
# LICENSEE             18423
# DBANAME              18347
# STREET NUMBER        18096
# STREET               18423
# CITY                 18422
# STATE                18422
# ZIPCODE              18422
# PHONE NUMBER         18423
# PRIMARY LICENSE      18423
# SECONDARY LICENSE    18423
# PRIMARY TYPE         18423
# SECONDARY TYPE       15952
# COUNTY               18423
# DISTRICT             18423
# SUBDIST              18423
# LATLNG                6428
# Assoc                18423
# First Name           18064
# Last Name            18420
# Phone                18423
# dtype: int64

# %%
data.isnull().sum()
# Out:
# LICENSEE                 0
# DBANAME                 76
# STREET NUMBER          327
# STREET                   0
# CITY                     1
# STATE                    1
# ZIPCODE                  1
# PHONE NUMBER             0
# PRIMARY LICENSE          0
# SECONDARY LICENSE        0
# PRIMARY TYPE             0
# SECONDARY TYPE        2471
# COUNTY                   0
# DISTRICT                 0
# SUBDIST                  0
# LATLNG               11995
# Assoc                    0
# First Name             359
# Last Name                3
# Phone                    0
# dtype: int64

# %%
data['CITY'].value_counts().head(10).plot.bar( figsize = (25, 15))
plt.title('Top Licence holders city', fontweight = 30, fontsize = 20)
plt.show()

# %%
data['STATE'].value_counts().head(10).plot.bar( figsize = (25, 15))
plt.title('Top Licence holders STATE', fontweight = 30, fontsize = 20)
plt.show()
